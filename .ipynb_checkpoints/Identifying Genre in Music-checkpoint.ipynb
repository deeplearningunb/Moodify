# %% [markdown]
# # Import Libraries

# %%
# feature extractoring and preprocessing data
import librosa as librosa
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
from PIL import Image
import pathlib
import csv
import soundfile as sf
from glob import glob
import IPython.display as ipd
import librosa.display
from IPython.core.display import HTML 
from IPython.core.display import Image, display

import io
from urllib.request import urlopen


# Preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler


#Keras
import keras

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Test Librosa library

# %%
# test with libraries
# Download https://www.kaggle.com/kinguistics/heartbeat-sounds/data

# data_dir = './music_genre_dataset/heartbeat-sounds/set_a'
# audio_files = glob(data_dir+'/*.wav')
# len(audio_files)

# %%
# for file in range(0, len(audio_files), 1):
#     audio, sfreq = librosa.load(audio_files[file])
#     time = np.arange(0, len(audio))/sfreq
    
#     fig, ax = plt.subplots()
#     ax.plot(time,audio)
#     ax.set(xlabel= 'Time em segundos', ylabel = "Amplitude")
#     plt.show()

# %%
#     X = librosa.stft(audio)
#     Xdb = librosa.amplitude_to_db(abs(X))
#     plt.figure(figsize=(14, 5))
#     librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
#     plt.colorbar()

# %% [markdown]
# # Extracting and feature music
#
# ## Dataset
# We use GTZAN genre collection dataset for classification.
#
# The dataset consists of 10 genres,each genre contains 100 songs. Total dataset: 1000 songs
#
#  - Blues
#  - Classical
#  - Country
#  - Disco
#  - Hiphop
#  - Jazz
#  - Metal
#  - Pop
#  - Reggae
#  - Rock

# %%
genres = 'blues classical country disco hiphop jazz metal pop reggae rock'.split()
for g in genres:
    data_dir = f'music_genre_dataset/genres/{g}'
    audio_files = glob(data_dir+'/*.wav')
    print(f'Total musics in genre {g}: ', len(audio_files))
# Out:
# Total musics in genre blues:  100
# Total musics in genre classical:  100
# Total musics in genre country:  100
# Total musics in genre disco:  100
# Total musics in genre hiphop:  100
# Total musics in genre jazz:  100
# Total musics in genre metal:  100
# Total musics in genre pop:  100
# Total musics in genre reggae:  100
# Total musics in genre rock:  100

# %%
# genres = 'blues classical country disco hiphop jazz metal pop reggae rock'.split()
# for g in genres:
#     data_dir = f'music_genre_dataset/genres/{g}'
#     audio_files = glob(data_dir+'/*.wav')
    
#     print('--------------------------------------------------------------------------------')
#     print(f'List musics in genre: {g}')
    
#     for file in range(0, len(audio_files), 1):
#         audio, sfreq = librosa.load(audio_files[file])
#         time = np.arange(0, len(audio))/sfreq
#         fig, ax = plt.subplots()
#         ax.plot(time,audio)
#         ax.set(xlabel= 'Time em segundos', ylabel = "Amplitude")
#         plt.show()
print("leutu")
# Out:
# leutu

# %% [markdown]
# # Extracting the Spectrogram for every Audio

# %%
cmap = plt.get_cmap('inferno')

plt.figure(figsize=(10,10))
genres = 'blues classical country disco hiphop jazz metal pop reggae rock'.split()
for g in genres:
    data_dir = f'music_genre_dataset/genres/{g}'
    audio_files = glob(data_dir+'/*.wav')
    pathlib.Path(f'./music_genre_dataset/img_data/{g}').mkdir(parents=True, exist_ok=True) 
    
    print('--------------------------------------------------------------------------------')
    print(f'List musics in genre: {g}')
    
    
    for filename in os.listdir(f'./music_genre_dataset/genres/{g}'):
        songname = f'./music_genre_dataset/genres/{g}/{filename}'
        
        y, sr = librosa.load(songname, mono=True, duration=5)
        plt.specgram(y, NFFT=2048, Fs=2, Fc=0, noverlap=128, cmap=cmap, sides='default', mode='default', scale='dB');
        plt.axis('off');
#         print(f'./music_genre_dataset/img_data/{g}/{filename[:-3].replace(".", "")}.png')
        file_save = f'./music_genre_dataset/img_data/{g}/{filename[:-3].replace(".", "")}.png'      
        plt.savefig(file_save)
#         plt.savefig(f'music_genre_dataset/img_data/{g}/{filename[:-3].replace(".", "")}.png')
        plt.clf() 
#         print("music_genre_dataset/img_data/{g}/)
           
        display(Image(file_save, width=1900, unconfined=True))
# Out:
# --------------------------------------------------------------------------------
# List musics in genre: blues
# --------------------------------------------------------------------------------
# List musics in genre: classical
# --------------------------------------------------------------------------------
# List musics in genre: country
# --------------------------------------------------------------------------------
# List musics in genre: disco
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-136-0b1399db3ead> in <module>
#      22         plt.savefig(file_save)
#      23 #         plt.savefig(f'music_genre_dataset/img_data/{g}/{filename[:-3].replace(".", "")}.png')
# ---> 24         plt.clf()
#      25 #         print("music_genre_dataset/img_data/{g}/)
#      26
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/pyplot.py in clf()
#     669     Clear the current figure.
#     670     """
# --> 671     gcf().clf()
#     672
#     673
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/figure.py in clf(self, keep_observers)
#    1428
#    1429         for ax in tuple(self.axes):  # Iterate over the copy.
# -> 1430             ax.cla()
#    1431             self.delaxes(ax)         # removes ax from self._axstack
#    1432
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/axes/_base.py in cla(self)
#    1015
#    1016         for name, spine in six.iteritems(self.spines):
# -> 1017             spine.cla()
#    1018
#    1019         self.ignore_existing_data_limits = True
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/spines.py in cla(self)
#     178         self._position = None  # clear position
#     179         if self.axis is not None:
# --> 180             self.axis.cla()
#     181
#     182     def is_frame_like(self):
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/axis.py in cla(self)
#     815                              rcParams['axes.grid.which'] in ('both', 'minor'))
#     816
# --> 817         self.reset_ticks()
#     818
#     819         self.converter = None
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/axis.py in reset_ticks(self)
#     838             pass
#     839         try:
# --> 840             self.set_clip_path(self.axes.patch)
#     841         except AttributeError:
#     842             pass
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/axis.py in set_clip_path(self, clippath, transform)
#     927     def set_clip_path(self, clippath, transform=None):
#     928         artist.Artist.set_clip_path(self, clippath, transform)
# --> 929         for child in self.majorTicks + self.minorTicks:
#     930             child.set_clip_path(clippath, transform)
#     931         self.stale = True
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/axis.py in __get__(self, instance, cls)
#     679             if self._major:
#     680                 instance.majorTicks = []
# --> 681                 tick = instance._get_tick(major=True)
#     682                 instance.majorTicks.append(tick)
#     683                 return instance.majorTicks
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    2162         else:
#    2163             tick_kw = self._minor_tick_kw
# -> 2164         return YTick(self.axes, 0, '', major=major, **tick_kw)
#    2165
#    2166     def _get_label(self):
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     175
#     176         self.tick1line = self._get_tick1line()
# --> 177         self.tick2line = self._get_tick2line()
#     178         self.gridline = self._get_gridline()
#     179
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/axis.py in _get_tick2line(self)
#     612                           markeredgewidth=self._width,
#     613                           zorder=self._zorder)
# --> 614         l.set_transform(self.axes.get_yaxis_transform(which='tick2'))
#     615         self._set_artist_props(l)
#     616         return l
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/axes/_base.py in get_yaxis_transform(self, which)
#     787         elif which == 'tick2':
#     788             # for cartesian projection, this is top spine
# --> 789             return self.spines['right'].get_spine_transform()
#     790         else:
#     791             raise ValueError('unknown value for which')
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/spines.py in get_spine_transform(self)
#     436     def get_spine_transform(self):
#     437         """get the spine transform"""
# --> 438         self._ensure_position_is_set()
#     439         what, how = self._spine_transform
#     440
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/spines.py in _ensure_position_is_set(self)
#     160             # default position
#     161             self._position = ('outward', 0.0)  # in points
# --> 162             self.set_position(self._position)
#     163
#     164     def register_axis(self, axis):
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/spines.py in set_position(self, position)
#     426
#     427         if self.axis is not None:
# --> 428             self.axis.reset_ticks()
#     429         self.stale = True
#     430
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/axis.py in reset_ticks(self)
#     838             pass
#     839         try:
# --> 840             self.set_clip_path(self.axes.patch)
#     841         except AttributeError:
#     842             pass
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/axis.py in set_clip_path(self, clippath, transform)
#     927     def set_clip_path(self, clippath, transform=None):
#     928         artist.Artist.set_clip_path(self, clippath, transform)
# --> 929         for child in self.majorTicks + self.minorTicks:
#     930             child.set_clip_path(clippath, transform)
#     931         self.stale = True
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/axis.py in __get__(self, instance, cls)
#     679             if self._major:
#     680                 instance.majorTicks = []
# --> 681                 tick = instance._get_tick(major=True)
#     682                 instance.majorTicks.append(tick)
#     683                 return instance.majorTicks
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    2162         else:
#    2163             tick_kw = self._minor_tick_kw
# -> 2164         return YTick(self.axes, 0, '', major=major, **tick_kw)
#    2165
#    2166     def _get_label(self):
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     175
#     176         self.tick1line = self._get_tick1line()
# --> 177         self.tick2line = self._get_tick2line()
#     178         self.gridline = self._get_gridline()
#     179
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/axis.py in _get_tick2line(self)
#     611                           markersize=self._size,
#     612                           markeredgewidth=self._width,
# --> 613                           zorder=self._zorder)
#     614         l.set_transform(self.axes.get_yaxis_transform(which='tick2'))
#     615         self._set_artist_props(l)
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     395         self._color = None
#     396         self.set_color(color)
# --> 397         self._marker = MarkerStyle(marker, fillstyle)
#     398
#     399         self._markevery = None
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/markers.py in __init__(self, marker, fillstyle)
#     187         self._marker_function = None
#     188         self.set_fillstyle(fillstyle)
# --> 189         self.set_marker(marker)
#     190
#     191     def __getstate__(self):
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/markers.py in set_marker(self, marker)
#     273
#     274         self._marker = marker
# --> 275         self._recache()
#     276
#     277     def get_path(self):
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/markers.py in _recache(self)
#     209         self._capstyle = 'butt'
#     210         self._filled = True
# --> 211         self._marker_function()
#     212
#     213     if six.PY3:
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/markers.py in _set_tickright(self)
#     707
#     708     def _set_tickright(self):
# --> 709         self._transform = Affine2D().scale(1.0, 1.0)
#     710         self._snap_threshold = 1.0
#     711         self._filled = False
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/transforms.py in scale(self, sx, sy)
#    2083             [[sx, 0.0, 0.0], [0.0, sy, 0.0], [0.0, 0.0, 1.0]], float)
#    2084         self._mtx = np.dot(scale_mtx, self._mtx)
# -> 2085         self.invalidate()
#    2086         return self
#    2087
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/transforms.py in invalidate(self)
#     137         value = self.INVALID
#     138         if self.is_affine:
# --> 139             value = self.INVALID_AFFINE
#     140         return self._invalidate_internal(value, invalidating_node=self)
#     141
#
# KeyboardInterrupt:

# %% [markdown]
# All the audio files get converted into their respective spectrograms .WE can noe easily extract features from them.

# %% [markdown]
# # Extracting features from Spectrogram
#
# We will extract
#
#  - Mel-frequency cepstral coefficients (MFCC)(20 in number)
#  - Spectral Centroid,
#  - Zero Crossing Rate
#  - Chroma Frequencies
#  - Spectral Roll-off.

# %%
header = 'filename chroma_stft rmse spectral_centroid spectral_bandwidth rolloff zero_crossing_rate'
for i in range(1, 21):
    header += f' mfcc{i}'
header += ' label'
header = header.split()

# %% [markdown]
# # Writing data to csv file¶
# We write the data to a csv file

# %%
file = open('./music_genre_dataset/data.csv', 'w', newline='')
with file:
    writer = csv.writer(file)
    writer.writerow(header)
genres = 'blues classical country disco hiphop jazz metal pop reggae rock'.split()
for g in genres:
#     data_dir = f'music_genre_dataset/genres/{g}'
    
    for filename in os.listdir(f'./music_genre_dataset/genres/{g}'):
        songname = f'./music_genre_dataset/genres/{g}/{filename}'
        y, sr = librosa.load(songname, mono=True, duration=30)
        chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)
        spec_cent = librosa.feature.spectral_centroid(y=y, sr=sr)
        spec_bw = librosa.feature.spectral_bandwidth(y=y, sr=sr)
        rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
        zcr = librosa.feature.zero_crossing_rate(y)
        mfcc = librosa.feature.mfcc(y=y, sr=sr)
        to_append = f'{file} {np.mean(chroma_stft)} {np.mean(spec_cent)} {np.mean(spec_bw)} {np.mean(rolloff)} {np.mean(zcr)}'    
        for e in mfcc:
            to_append += f' {np.mean(e)}'
        to_append += f' {g}'
        file = open('./music_genre_dataset/data.csv', 'a', newline='')
        with file:
            writer = csv.writer(file)
            writer.writerow(to_append.split())

# %%
# file = open('./music_genre_dataset/data.csv', 'w', newline='')
# with file:
#     writer = csv.writer(file)
#     writer.writerow(header)
# genres = 'blues classical country disco hiphop jazz metal pop reggae rock'.split()
# for g in genres:
#     print(os.listdir(f'./music_genre_dataset/genres/{g}')
        
    
#     for filename in os.listdir(f'./music_genre_dataset/genres/{g}'):
#         songname = f'./music_genre_dataset/genres/{g}/{filename}'
#         y, sr = librosa.load(songname, mono=True, duration=30)
#         chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)
#         spec_cent = librosa.feature.spectral_centroid(y=y, sr=sr)
#         spec_bw = librosa.feature.spectral_bandwidth(y=y, sr=sr)
#         rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
#         zcr = librosa.feature.zero_crossing_rate(y)
#         mfcc = librosa.feature.mfcc(y=y, sr=sr)
#         to_append = f'{filename} {np.mean(chroma_stft)} {np.mean(rmse)} {np.mean(spec_cent)} {np.mean(spec_bw)} {np.mean(rolloff)} {np.mean(zcr)}'    
#         for e in mfcc:
#             to_append += f' {np.mean(e)}'
#         to_append += f' {g}'
#         file = open('./music_genre_dataset/data.csv', 'a', newline='')
#         with file:
#             writer = csv.writer(file)
#             writer.writerow(to_append.split())

# %% [markdown]
# # Data Analising with padas

# %%
data = pd.read_csv('./music_genre_dataset/data.csv')
data.head()

# %%
# Dropping unneccesary columns
data = data.drop(['filename'],axis=1)

# %% [markdown]
# # Encode labels

# %%
genre_list = data.iloc[:, -1]
encoder = LabelEncoder()
y = encoder.fit_transform(genre_list)

# %% [markdown]
# # Scaling feature columns

# %%
scaler = StandardScaler()
X = scaler.fit_transform(np.array(data.iloc[:, :-1], dtype = float))

# %% [markdown]
# # Diving data into training and test

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
len(y_train)

# %%
len(y_test)

# %%
X_train[10]

# %% [markdown]
# # Classification with Keras

# %%
from keras import models
from keras import layers

model = models.Sequential()
model.add(layers.Dense(256, activation='relu', input_shape=(X_train.shape[1],)))

model.add(layers.Dense(128, activation='relu'))

model.add(layers.Dense(64, activation='relu'))

model.add(layers.Dense(10, activation='softmax'))

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(X_train,
                    y_train,
                    epochs=20,
                    batch_size=128)

# %%
test_loss, test_acc = model.evaluate(X_test,y_test)

# %%
print('test_acc: ',test_acc)

# %% [markdown]
# # Validating out approuch

# %%
x_val = X_train[:200]
partial_x_train = X_train[200:]

y_val = y_train[:200]
partial_y_train = y_train[200:]

# %%
model = models.Sequential()
model.add(layers.Dense(512, activation='relu', input_shape=(X_train.shape[1],)))
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(partial_x_train,
          partial_y_train,
          epochs=30,
          batch_size=512,
          validation_data=(x_val, y_val))
results = model.evaluate(X_test, y_test)

# %%
results

# %% [markdown]
# # Predictions on Test Data

# %%
predictions = model.predict(X_test)

# %%
predictions[0].shape

# %%
np.sum(predictions[0])

# %%
np.argmax(predictions[0])
